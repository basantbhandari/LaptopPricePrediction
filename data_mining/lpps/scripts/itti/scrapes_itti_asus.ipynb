# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from beautifulsoup4->bs4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
laptop_name=[]
laptop_price=[]
page_num=input("Enter number of pages:")
for i in range(1,int(page_num)+1):
    url="https://itti.com.np/laptops-by-brands/asus-laptop-nepal?p="+str(i)
    req=requests.get(url)
    content=BeautifulSoup(req.content,'html.parser')
    name=content.find_all('h2',{"class":"product name product-item-name product-name"})
    price=content.find_all('span',{"class":"price"})
    print("Laptops in page" + str(i))
   
    print(len(name))
    print(len(price))
    
    for i in name:
        laptop_name.append(i.text)
    for i in price:
        laptop_price.append(i.text)
# Out:
# Enter number of pages:4
# Laptops in page1
# 12
# 12
# Laptops in page2
# 12
# 12
# Laptops in page3
# 12
# 12
# Laptops in page4
# 12
# 12

# %%
for i in laptop_name:
    print(i)
# Out:
#                                             Asus VivoBook 15 X515MA 10th Gen Celeron / 4GB RAM / 256GB SSD / 15.6" FHD display
#
#
#
#                                             Asus VivoBook E410MA Celeron / 4GB RAM / 256GB SSD / 14" Display / Magic Numpad
#
#
#
#                                             Asus VivoBook Flip 14 TP401MA 8th Gen Celeron / 4GB RAM / 128GB SSD / 14" 360-degree TouchScreen Display / Windows Genuine
#
#
#
#                                             Asus VivoBook 14 X415JA i3 10th Gen / 4GB RAM/ 256GB SSD / 14" FHD display
#
#
#
#                                             Asus VivoBook 14 X413EA i3 11th Gen / 4GB RAM / 256GB SSD / 14" FHD display / Metal body / Long battery
#
#
#
#                                             ASUS VIVOBOOK X409JA i5 10TH GEN/ 4GB RAM/ 256GB SSD/ 14" FHD/ WINDOWS GENUINE
#
#
#
#                                             Asus VivoBook Flip 14 TP412FA i3 10th Gen / 4GB RAM / 256GB SSD / 14" FHD 360 Touch display / Stylus Support
#
#
#
#                                             Asus VivoBook 14 X415JA i5 10th Gen / 8GB RAM/ 256GB SSD / 14"FHD display / Backlit Keyboard
#
#
#
#                                             Asus VivoBook 15 M513IA Ryzen 5 4500U / 8GB RAM/ 256GB SSD / 15.6" FHD display
#
#
#
#                                             ASUS VIVOBOOK X509JP i5 10TH GEN/ NVIDIA MX330/ 4GB RAM/ 1TB HDD/ 15.6FHD/ BACKLIGHT KEYBOARD/ WINDOWS GENUINE
#
#
#
#                                             Asus VivoBook 15 X515JA i5 10th Gen / 8GB RAM / 512GB SSD / 15.6" FHD display / Backlit keyboard
#
#
#
#                                             ASUS VIVOBOOK X515EA i5 11TH GEN/ 8GB/ 256GB/ 15.6" FHD/ LONG BATTERY
#
#
#
#                                             Asus VivoBook 14 X413EA i5 11th Gen / 8GB / 256GB / 14" FHD display / Metal Body / Long Battery
#
#
#
#                                             Asus VivoBook 15 K513EA i5 11th Gen / 8GB RAM / 512GB SSD/ 15.6" FHD
#
#
#
#                                             ASUS VIVOBOOK K403FA i5 10TH GEN/ 8GB RAM/ 512GB SSD/ 24 HOURS BATTERY/ 14" FHD
#
#
#
#                                             Asus VivoBook Flip TM420IA RYZEN 4500U / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
#
#
#
#                                             ASUS VIVOBOOK X415JA i7 10TH GEN/ 8GB RAM/ 256GB SSD / BACKLIGHT KEYBOARD 14" FHD
#
#
#
#                                             ASUS VIVOBOOK S15 S533FL i5 10TH GEN/ 8GB RAM/ 512GB SSD/  MX250/ 15.6" FHD
#
#
#
#                                             Asus VivoBook Flip 14 TM420UA Ryzen 5 5500U / 8GB RAM/ 512GB SSD / 14" FHD 360 Touch display / Stylus support
#
#
#
#                                             Asus VivoBook S14 S431 I7 8th Gen / NVIDIA MX250 / 8GB RAM / 256GB SSD/ 14'' FHD Display / Backlight Keyboard
#
#
#
#                                             Asus VivoBook Flip 14 TP470EA i5 11th Gen 1135G7 / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
#
#
#
#                                             Asus VivoBook 15 X515JP i7 10th Gen / NVIDIA MX330 / 8GB RAM/ 512GB SSD / 15.6" FHD display
#
#
#
#                                             Asus TUF F15 Gaming Laptop i5 10Th Gen / GTX 1650/ 8GB RAM / 512GB SSD / 15.6" FHD 144Hz display
#
#
#
#                                             Asus ZenBook 13 UX325JA I5 10 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
#
#
#
#                                             ASUS ZenBook 14 UX425JA I5 10 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
#
#
#
#                                             Asus VivoBook 15 X515EP i7 11th Gen / NVIDIA MX330 / 8GB RAM / 512GB SSD / 15.6" FHD display
#
#
#
#                                             ASUS ZenBook 13 UX325EA I5 11 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
#
#
#
#                                             Asus ZenBook 14 UX425EA I5 11 Gen / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
#
#
#
#                                             ASUS VIVOBOOK K403FA i7 10TH GEN/ 16GB RAM/ 512GB SSD/ 24 HOURS BATTERY/ 14" FHD
#
#
#
#                                             Asus TUF F15 Gaming Laptop i5 10Th Gen / GTX 1650Ti / 16GB RAM / 512GB SSD / 15.6" FHD 144Hz display
#
#
#
#                                             AsusS ZenBook UX463FA i5 10th Gen / 8GB RAM / 512GB SSD / Magic NumPad / Stylus / 14" FHD 360-degree Touchscreen display
#
#
#
#                                             Asus TUF A15 Gaming Laptop Ryzen 5 4600H/ 8GB RAM/ 512GB SSD/ GTX 1650Ti/ 15.6" FHD 144Hz
#
#
#
#                                             Asus VivoBook 15 K513EQ i7 11th Gen / NVIDIA MX350 / 8GB RAM / 512GB SSD / 15.6" FHD display
#
#
#
#                                             Asus ROG Strix G531GT  i5 9TH GEN/ 8GB RAM/ 512GB SSD/ GTX 1650/ 15.6" FHD 144Hz
#
#
#
#                                             Asus VivoBook Flip 14 TP470EA i7 11th Gen 1135G7 / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
#
#
#
#                                             Asus VivoBook S15 S533EA i7 11th Gen / 16GB RAM / 512GB SSD / Iris Xe graphics / 15.6" FHD Display
#
#
#
#                                             Asus VivoBook S15 S533JQ i7 10th Gen / 16GB RAM / 512GB SSD / Nvidia MX350 / 15.6" FHD Display
#
#
#
#                                             Asus ZenBook 14 UX434FQ i5 10th Gen / NVIDIA MX350 / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
#
#
#
#                                             Asus ROG Strix G15 G512LI i5 10TH GEN / GTX 1650TI / 15.6" FHD 144Hz / 16GB RAM/ 512GB SSD
#
#
#
#                                             Asus ZenBook Flip 13 UX363EA i5 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / Stylus / 13.3" FHD 360-degree Touchscreen display
#
#
#
#                                             Asus TUF F15 Gaming Laptop i7 10Th Gen 8 Core / GTX 1650 / 8GB RAM / 512GB SSD / 15.6" FHD 144Hz display
#
#
#
#                                             Asus ZenBook 13 UX325JA I7 10 GEN / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
#
#
#
#                                             Asus TUF A15 FA506II Gaming Laptop Ryzen 7 4800H/ 16GB RAM/ 512GB SSD/ GTX 1650Ti/ 15.6" FHD 144Hz
#
#
#
#                                             Asus ZenBook 14 UX435EG i5 11th Gen / MX450 / 8GB RAM / 512GB SSD / ScreenPad / 14" FHD Touch
#
#
#
#                                             Asus ZenBook 13 UX325EA I7 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
#
#
#
#                                             Asus ZenBook 14 UX425EA I7 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
#
#
#
#                                             Asus TUF A15 FA506IU Gaming Laptop Ryzen 7 4800H/ 16GB RAM/ 512GB SSD/ 90WHR BATTERY/ GTX 1660Ti/ 15.6" FHD 144Hz
#
#
#
#                                             Asus TUF A17 FA706IU Gaming Laptop Ryzen 7 4800H/ 8GB RAM/ 512GB SSD/ GTX 1660Ti/ 17.3" FHD 144Hz

# %%
for i in laptop_price:
    print(i)
# Out:
# NPR48,000.00
# NPR48,000.00
# NPR57,700.00
# NPR63,000.00
# NPR67,000.00
# NPR75,000.00
# NPR83,000.00
# NPR83,000.00
# NPR87,000.00
# NPR87,000.00
# NPR88,000.00
# NPR90,000.00
# NPR95,000.00
# NPR102,000.00
# NPR106,000.00
# NPR108,000.00
# NPR115,000.00
# NPR116,000.00
# NPR116,000.00
# NPR120,000.00
# NPR120,000.00
# NPR122,000.00
# NPR122,000.00
# NPR125,000.00
# NPR125,000.00
# NPR126,000.00
# NPR127,000.00
# NPR127,000.00
# NPR131,000.00
# NPR132,000.00
# NPR134,000.00
# NPR135,000.00
# NPR135,000.00
# NPR137,000.00
# NPR138,000.00
# NPR141,000.00
# NPR141,000.00
# NPR142,000.00
# NPR143,000.00
# NPR146,000.00
# NPR148,000.00
# NPR148,000.00
# NPR152,000.00
# NPR153,000.00
# NPR154,000.00
# NPR154,000.00
# NPR161,000.00
# NPR167,000.00

# %%
for i in range(len(laptop_name)):
    print(laptop_name[i] + '\t ' + laptop_price[i])
# Out:
#                                             Asus VivoBook 15 X515MA 10th Gen Celeron / 4GB RAM / 256GB SSD / 15.6" FHD display
# 	 NPR48,000.00
#
#
#                                             Asus VivoBook E410MA Celeron / 4GB RAM / 256GB SSD / 14" Display / Magic Numpad
# 	 NPR48,000.00
#
#
#                                             Asus VivoBook Flip 14 TP401MA 8th Gen Celeron / 4GB RAM / 128GB SSD / 14" 360-degree TouchScreen Display / Windows Genuine
# 	 NPR57,700.00
#
#
#                                             Asus VivoBook 14 X415JA i3 10th Gen / 4GB RAM/ 256GB SSD / 14" FHD display
# 	 NPR63,000.00
#
#
#                                             Asus VivoBook 14 X413EA i3 11th Gen / 4GB RAM / 256GB SSD / 14" FHD display / Metal body / Long battery
# 	 NPR67,000.00
#
#
#                                             ASUS VIVOBOOK X409JA i5 10TH GEN/ 4GB RAM/ 256GB SSD/ 14" FHD/ WINDOWS GENUINE
# 	 NPR75,000.00
#
#
#                                             Asus VivoBook Flip 14 TP412FA i3 10th Gen / 4GB RAM / 256GB SSD / 14" FHD 360 Touch display / Stylus Support
# 	 NPR83,000.00
#
#
#                                             Asus VivoBook 14 X415JA i5 10th Gen / 8GB RAM/ 256GB SSD / 14"FHD display / Backlit Keyboard
# 	 NPR83,000.00
#
#
#                                             Asus VivoBook 15 M513IA Ryzen 5 4500U / 8GB RAM/ 256GB SSD / 15.6" FHD display
# 	 NPR87,000.00
#
#
#                                             ASUS VIVOBOOK X509JP i5 10TH GEN/ NVIDIA MX330/ 4GB RAM/ 1TB HDD/ 15.6FHD/ BACKLIGHT KEYBOARD/ WINDOWS GENUINE
# 	 NPR87,000.00
#
#
#                                             Asus VivoBook 15 X515JA i5 10th Gen / 8GB RAM / 512GB SSD / 15.6" FHD display / Backlit keyboard
# 	 NPR88,000.00
#
#
#                                             ASUS VIVOBOOK X515EA i5 11TH GEN/ 8GB/ 256GB/ 15.6" FHD/ LONG BATTERY
# 	 NPR90,000.00
#
#
#                                             Asus VivoBook 14 X413EA i5 11th Gen / 8GB / 256GB / 14" FHD display / Metal Body / Long Battery
# 	 NPR95,000.00
#
#
#                                             Asus VivoBook 15 K513EA i5 11th Gen / 8GB RAM / 512GB SSD/ 15.6" FHD
# 	 NPR102,000.00
#
#
#                                             ASUS VIVOBOOK K403FA i5 10TH GEN/ 8GB RAM/ 512GB SSD/ 24 HOURS BATTERY/ 14" FHD
# 	 NPR106,000.00
#
#
#                                             Asus VivoBook Flip TM420IA RYZEN 4500U / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
# 	 NPR108,000.00
#
#
#                                             ASUS VIVOBOOK X415JA i7 10TH GEN/ 8GB RAM/ 256GB SSD / BACKLIGHT KEYBOARD 14" FHD
# 	 NPR115,000.00
#
#
#                                             ASUS VIVOBOOK S15 S533FL i5 10TH GEN/ 8GB RAM/ 512GB SSD/  MX250/ 15.6" FHD
# 	 NPR116,000.00
#
#
#                                             Asus VivoBook Flip 14 TM420UA Ryzen 5 5500U / 8GB RAM/ 512GB SSD / 14" FHD 360 Touch display / Stylus support
# 	 NPR116,000.00
#
#
#                                             Asus VivoBook S14 S431 I7 8th Gen / NVIDIA MX250 / 8GB RAM / 256GB SSD/ 14'' FHD Display / Backlight Keyboard
# 	 NPR120,000.00
#
#
#                                             Asus VivoBook Flip 14 TP470EA i5 11th Gen 1135G7 / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
# 	 NPR120,000.00
#
#
#                                             Asus VivoBook 15 X515JP i7 10th Gen / NVIDIA MX330 / 8GB RAM/ 512GB SSD / 15.6" FHD display
# 	 NPR122,000.00
#
#
#                                             Asus TUF F15 Gaming Laptop i5 10Th Gen / GTX 1650/ 8GB RAM / 512GB SSD / 15.6" FHD 144Hz display
# 	 NPR122,000.00
#
#
#                                             Asus ZenBook 13 UX325JA I5 10 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
# 	 NPR125,000.00
#
#
#                                             ASUS ZenBook 14 UX425JA I5 10 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
# 	 NPR125,000.00
#
#
#                                             Asus VivoBook 15 X515EP i7 11th Gen / NVIDIA MX330 / 8GB RAM / 512GB SSD / 15.6" FHD display
# 	 NPR126,000.00
#
#
#                                             ASUS ZenBook 13 UX325EA I5 11 GEN / 8GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
# 	 NPR127,000.00
#
#
#                                             Asus ZenBook 14 UX425EA I5 11 Gen / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
# 	 NPR127,000.00
#
#
#                                             ASUS VIVOBOOK K403FA i7 10TH GEN/ 16GB RAM/ 512GB SSD/ 24 HOURS BATTERY/ 14" FHD
# 	 NPR131,000.00
#
#
#                                             Asus TUF F15 Gaming Laptop i5 10Th Gen / GTX 1650Ti / 16GB RAM / 512GB SSD / 15.6" FHD 144Hz display
# 	 NPR132,000.00
#
#
#                                             AsusS ZenBook UX463FA i5 10th Gen / 8GB RAM / 512GB SSD / Magic NumPad / Stylus / 14" FHD 360-degree Touchscreen display
# 	 NPR134,000.00
#
#
#                                             Asus TUF A15 Gaming Laptop Ryzen 5 4600H/ 8GB RAM/ 512GB SSD/ GTX 1650Ti/ 15.6" FHD 144Hz
# 	 NPR135,000.00
#
#
#                                             Asus VivoBook 15 K513EQ i7 11th Gen / NVIDIA MX350 / 8GB RAM / 512GB SSD / 15.6" FHD display
# 	 NPR135,000.00
#
#
#                                             Asus ROG Strix G531GT  i5 9TH GEN/ 8GB RAM/ 512GB SSD/ GTX 1650/ 15.6" FHD 144Hz
# 	 NPR137,000.00
#
#
#                                             Asus VivoBook Flip 14 TP470EA i7 11th Gen 1135G7 / 8GB RAM / 512GB SSD / 14" FHD 360 Touch display / Stylus support
# 	 NPR138,000.00
#
#
#                                             Asus VivoBook S15 S533EA i7 11th Gen / 16GB RAM / 512GB SSD / Iris Xe graphics / 15.6" FHD Display
# 	 NPR141,000.00
#
#
#                                             Asus VivoBook S15 S533JQ i7 10th Gen / 16GB RAM / 512GB SSD / Nvidia MX350 / 15.6" FHD Display
# 	 NPR141,000.00
#
#
#                                             Asus ZenBook 14 UX434FQ i5 10th Gen / NVIDIA MX350 / 8GB RAM / 512GB SSD / Magic NumPad / 14" FHD display
# 	 NPR142,000.00
#
#
#                                             Asus ROG Strix G15 G512LI i5 10TH GEN / GTX 1650TI / 15.6" FHD 144Hz / 16GB RAM/ 512GB SSD
# 	 NPR143,000.00
#
#
#                                             Asus ZenBook Flip 13 UX363EA i5 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / Stylus / 13.3" FHD 360-degree Touchscreen display
# 	 NPR146,000.00
#
#
#                                             Asus TUF F15 Gaming Laptop i7 10Th Gen 8 Core / GTX 1650 / 8GB RAM / 512GB SSD / 15.6" FHD 144Hz display
# 	 NPR148,000.00
#
#
#                                             Asus ZenBook 13 UX325JA I7 10 GEN / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
# 	 NPR148,000.00
#
#
#                                             Asus TUF A15 FA506II Gaming Laptop Ryzen 7 4800H/ 16GB RAM/ 512GB SSD/ GTX 1650Ti/ 15.6" FHD 144Hz
# 	 NPR152,000.00
#
#
#                                             Asus ZenBook 14 UX435EG i5 11th Gen / MX450 / 8GB RAM / 512GB SSD / ScreenPad / 14" FHD Touch
# 	 NPR153,000.00
#
#
#                                             Asus ZenBook 13 UX325EA I7 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
# 	 NPR154,000.00
#
#
#                                             Asus ZenBook 14 UX425EA I7 11th Gen / 16GB RAM / 512GB SSD / Magic NumPad / 13.3" FHD display
# 	 NPR154,000.00
#
#
#                                             Asus TUF A15 FA506IU Gaming Laptop Ryzen 7 4800H/ 16GB RAM/ 512GB SSD/ 90WHR BATTERY/ GTX 1660Ti/ 15.6" FHD 144Hz
# 	 NPR161,000.00
#
#
#                                             Asus TUF A17 FA706IU Gaming Laptop Ryzen 7 4800H/ 8GB RAM/ 512GB SSD/ GTX 1660Ti/ 17.3" FHD 144Hz
# 	 NPR167,000.00
